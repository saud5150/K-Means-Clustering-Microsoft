# %% [markdown]
# # Species Segmentation Using K means clustering
# ### Iris

# %%
email = skamran.bese18seecs@seecs.edu.pk

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# Loading the data

# %%
data = pd.read_csv('Iris.csv');

data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# Plotting the data

# %%
plt.scatter(data['sepal_length'], data['petal_length'])
plt.show()

# %%
x = data.iloc[:, :]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# Clustering

# %%
km = KMeans(4)

km.fit(x)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# Clustering results

# %%
df = km.fit_predict(x)

# %%
newdf = data.copy()
newdf['pred'] = df
newdf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  pred
# 0             5.1          3.5           1.4          0.2     0
# 1             4.9          3.0           1.4          0.2     0
# 2             4.7          3.2           1.3          0.2     0
# 3             4.6          3.1           1.5          0.2     0
# 4             5.0          3.6           1.4          0.2     0
# ..            ...          ...           ...          ...   ...
# 145           6.7          3.0           5.2          2.3     3
# 146           6.3          2.5           5.0          1.9     1
# 147           6.5          3.0           5.2          2.0     1
# 148           6.2          3.4           5.4          2.3     3
# 149           5.9          3.0           5.1          1.8     1
#
# [150 rows x 5 columns]

# %% [markdown]
# Plot the data

# %%
plt.scatter(newdf['sepal_length'], newdf['petal_length'], c = newdf['pred'], cmap = 'rainbow')
plt.show()
